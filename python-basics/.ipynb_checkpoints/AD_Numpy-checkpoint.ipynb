# %%
#Numpy is a python pacage or a library for scitific computing ,numeric  computing and mainly used in data scienc and machine learning
#numpy introduce a power full data structure called NDarray (n_dimensional arry)

#array- array is a collection hetrogenuos element denoted by [] with space seperated values 
#array allows used to stored and manipulate massive data and incrideble speed
